# %% [markdown]
# ### In tis notebook, a sample and simple line graph is made

# %%
# import some libraries
import matplotlib.pyplot as plt

# %%
# make two arrays
x=[1,2,3,4]
y=[2,4,6,8]

plt.plot(x,y)
plt.xlabel("X values")
plt.ylabel("Y values")
plt.show()
